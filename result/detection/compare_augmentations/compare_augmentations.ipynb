# %%
import os
from os.path import join as pj
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

# %% [markdown]
# ### --- compare AP, precision, recall ---

# %%
refinedet_shear = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Shear/class_df.csv')
refinedet_shear = refinedet_shear.drop('Unnamed: 0', axis=1)
refinedet_translate = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Translate/class_df.csv')
refinedet_translate = refinedet_translate.drop('Unnamed: 0', axis=1)
refinedet_rotate = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Rotate/class_df.csv')
refinedet_rotate = refinedet_rotate.drop('Unnamed: 0', axis=1)
refinedet_autocontrast = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_AutoContrast/class_df.csv')
refinedet_autocontrast = refinedet_autocontrast.drop('Unnamed: 0', axis=1)
refinedet_invert = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Invert/class_df.csv')
refinedet_invert = refinedet_invert.drop('Unnamed: 0', axis=1)
refinedet_equalize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Equalize/class_df.csv')
refinedet_equalize = refinedet_equalize.drop('Unnamed: 0', axis=1)
refinedet_solarize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Solarize/class_df.csv')
refinedet_solarize = refinedet_solarize.drop('Unnamed: 0', axis=1)
refinedet_posterize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Posterize/class_df.csv')
refinedet_posterize = refinedet_posterize.drop('Unnamed: 0', axis=1)
refinedet_contrast = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Contrast/class_df.csv')
refinedet_contrast = refinedet_contrast.drop('Unnamed: 0', axis=1)
refinedet_color = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Color/class_df.csv')
refinedet_color = refinedet_color.drop('Unnamed: 0', axis=1)
refinedet_brightness = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Brightness/class_df.csv')
refinedet_brightness = refinedet_brightness.drop('Unnamed: 0', axis=1)
refinedet_sharpness = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Sharpness/class_df.csv')
refinedet_sharpness = refinedet_sharpness.drop('Unnamed: 0', axis=1)
refinedet_cutout = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Cutout/class_df.csv')
refinedet_cutout = refinedet_cutout.drop('Unnamed: 0', axis=1)

# %%
ap_df = pd.DataFrame(columns=["AP", "precision", "recall"])
ap_df = ap_df.append(refinedet_shear, ignore_index=True)
ap_df = ap_df.append(refinedet_translate, ignore_index=True)
ap_df = ap_df.append(refinedet_rotate, ignore_index=True)
ap_df = ap_df.append(refinedet_autocontrast, ignore_index=True)
ap_df = ap_df.append(refinedet_invert, ignore_index=True)
ap_df = ap_df.append(refinedet_equalize, ignore_index=True)
ap_df = ap_df.append(refinedet_solarize, ignore_index=True)
ap_df = ap_df.append(refinedet_posterize, ignore_index=True)
ap_df = ap_df.append(refinedet_contrast, ignore_index=True)
ap_df = ap_df.append(refinedet_color, ignore_index=True)
ap_df = ap_df.append(refinedet_brightness, ignore_index=True)
ap_df = ap_df.append(refinedet_sharpness, ignore_index=True)
ap_df = ap_df.append(refinedet_cutout, ignore_index=True)
ap_df.index = [
    "refinedet_shear",
    "refinedet_translate",
    "refinedet_rotate",
    "refinedet_autocontrast",
    "refinedet_invert",
    "refinedet_equalize",
    "refinedet_solarize",
    "refinedet_posterize",
    "refinedet_contrast",
    "refinedet_color",
    "refinedet_brightness",
    "refinedet_sharpness",
    "refinedet_cutout",
]
ap_df.style.highlight_max(axis=0, color='red')
# Out:
# <style  type="text/css" >
#     #T_b005768a_18d0_11eb_a7ba_411a7796e7f3row1_col1 {
#             background-color:  red;
#         }    #T_b005768a_18d0_11eb_a7ba_411a7796e7f3row6_col2 {
#             background-color:  red;
#         }    #T_b005768a_18d0_11eb_a7ba_411a7796e7f3row12_col0 {
#             background-color:  red;
#         }</style><table id="T_b005768a_18d0_11eb_a7ba_411a7796e7f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AP</th>        <th class="col_heading level0 col1" >precision</th>        <th class="col_heading level0 col2" >recall</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b005768a_18d0_11eb_a7ba_411a7796e7f3level0_row0" class="row_heading level0 row0" >refinedet_shear</th>
#                         <td id="T_b005768a_18d0_11eb_a7ba_411a7796e7f3row0_col0" class="data row0 col0" >0.648126</td>
# ...

# %% [markdown]
# ### --- compare accuracy per size ---

# %%
det_each_size_df = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806/each_size_df.csv')
det_each_size_df["order"] = det_each_size_df["Insect_size"].apply(lambda x: np.floor(np.log2(x)))
insect_size = np.asarray(det_each_size_df["order"])
idx, count = np.unique(insect_size, return_counts=True)
insect_size_df = pd.DataFrame({"order": idx, "count": count})

# %%
refinedet_shear = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Shear/all_size_df.csv')
refinedet_shear = refinedet_shear.drop('Unnamed: 0', axis=1)
refinedet_translate = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Translate/all_size_df.csv')
refinedet_translate = refinedet_translate.drop('Unnamed: 0', axis=1)
refinedet_rotate = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Rotate/all_size_df.csv')
refinedet_rotate = refinedet_rotate.drop('Unnamed: 0', axis=1)
refinedet_autocontrast = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_AutoContrast/all_size_df.csv')
refinedet_autocontrast = refinedet_autocontrast.drop('Unnamed: 0', axis=1)
refinedet_invert = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Invert/all_size_df.csv')
refinedet_invert = refinedet_invert.drop('Unnamed: 0', axis=1)
refinedet_equalize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Equalize/all_size_df.csv')
refinedet_equalize = refinedet_equalize.drop('Unnamed: 0', axis=1)
refinedet_solarize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Solarize/all_size_df.csv')
refinedet_solarize = refinedet_solarize.drop('Unnamed: 0', axis=1)
refinedet_posterize = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Posterize/all_size_df.csv')
refinedet_posterize = refinedet_posterize.drop('Unnamed: 0', axis=1)
refinedet_contrast = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Contrast/all_size_df.csv')
refinedet_contrast = refinedet_contrast.drop('Unnamed: 0', axis=1)
refinedet_color = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Color/all_size_df.csv')
refinedet_color = refinedet_color.drop('Unnamed: 0', axis=1)
refinedet_brightness = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Brightness/all_size_df.csv')
refinedet_brightness = refinedet_brightness.drop('Unnamed: 0', axis=1)
refinedet_sharpness = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Sharpness/all_size_df.csv')
refinedet_sharpness = refinedet_sharpness.drop('Unnamed: 0', axis=1)
refinedet_cutout = pd.read_csv('/home/tanida/workspace/Insect_Phenology_Detector/figure/detection/RefineDet/crop_b2/tcb5_im512_freeze_20200806_use_extra_Cutout/all_size_df.csv')
refinedet_cutout = refinedet_cutout.drop('Unnamed: 0', axis=1)

# %%
insect_size_df["Insect_size"] = refinedet_shear["Insect_size"]
insect_size_df
# Out:
#    order  count   Insect_size
# 0    7.0     15    224.800000
# 1    8.0    181    394.436464
# 2    9.0    189    726.137566
# 3   10.0     84   1420.392857
# 4   11.0     50   2870.260000
# 5   12.0     38   6288.526316
# 6   13.0     47  11189.978723
# 7   14.0     16  22611.437500
# 8   15.0      3  37326.666667

# %%
all_df = pd.DataFrame()
#all_df["order"] = insect_size_df["order"]
#all_df["count"] = insect_size_df["count"]
all_df["refinedet_shear"] = refinedet_shear["Accuracy"]
all_df["refinedet_translate"] = refinedet_translate["Accuracy"]
all_df["refinedet_rotate"] = refinedet_rotate["Accuracy"]
all_df["refinedet_autocontrast"] = refinedet_autocontrast["Accuracy"]
all_df["refinedet_invert"] = refinedet_invert["Accuracy"]
all_df["refinedet_equalize"] = refinedet_equalize["Accuracy"]
all_df["refinedet_solarize"] = refinedet_solarize["Accuracy"]
all_df["refinedet_posterize"] = refinedet_posterize["Accuracy"]
all_df["refinedet_contrast"] = refinedet_contrast["Accuracy"]
all_df["refinedet_color"] = refinedet_color["Accuracy"]
all_df["refinedet_brightness"] = refinedet_brightness["Accuracy"]
all_df["refinedet_sharpness"] = refinedet_sharpness["Accuracy"]
all_df["refinedet_cutout"] = refinedet_cutout["Accuracy"]
all_df.style.highlight_max(axis=1, color='red')
# Out:
# <style  type="text/css" >
#     #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row0_col4 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row0_col6 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row0_col12 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row1_col6 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row2_col6 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row3_col6 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row4_col3 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row4_col4 {
#             background-color:  red;
#         }    #T_b116ca2e_18d0_11eb_a7ba_411a7796e7f3row4_col6 {
#             background-color:  red;
# ...
